# %%
from prettytable import PrettyTable
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statistics

# %% [markdown]
# # Sets Pre - Processing

# %% [markdown]
# ## Set A

# %%
df_merged_1 = pd.read_csv('df_set1_final.csv')

# %%
emo_seta = ['Sad','Happy','Angry','Neutral', 'Happy', 'Sad', 'Neutral','Sad','Happy','Sad','Angry','Sad','Happy','Neutral','Angry','Happy','Angry','Neutral','Angry','Neutral','Angry','Neutral','Happy','Neutral','Sad']

# %%
emotions = ['Happy', 'Sad', 'Angry', 'Neutral']
dfs = []
for j in emotions:
  temp = {}
  temp['Rec_Session_Id'] = list(df_merged_1['Rec_Session_Id'].values)
  temp['total_gad_score'] = list(df_merged_1['total_gad_score'].values)
  temp['total_phq_score'] = list(df_merged_1['total_phq_score'].values)
  temp['total_pss_score'] = list(df_merged_1['total_pss_score'].values)
  temp['total_panas_pos'] = list(df_merged_1['total_panas_pos'].values)
  temp['total_panas_neg'] = list(df_merged_1['total_panas_neg'].values)
  temp['total_fluency_score'] = list(df_merged_1['total_fluency_score'].values)

  for i in range(len(emo_seta)):
    if emo_seta[i] == j:
      # temp = {}
      temp[f'q{i+1}_val_seta'] = list(df_merged_1[f'q{i+1}_val_seta'].values)
      temp[f'q{i+1}_arous_seta'] = list(df_merged_1[f'q{i+1}_arous_seta'].values)
      temp[f'rt{i+1}a'] = list(df_merged_1[f'rt{i+1}a'].values)

  globals()[f'df1_{j}'] = pd.DataFrame.from_dict(temp)
  dfs.append(globals()[f'df1_{j}'] )

# %%
unh_dep_tot1 = 0
h_dep_tot1 = 0

for i in range(len(df_merged_1['total_phq_score'].values)):
  if df_merged_1['total_phq_score'].values[i] >9:
    unh_dep_tot1 +=1
  else:
    h_dep_tot1 +=1

# %%
print(unh_dep_tot1)
print(h_dep_tot1)
total1_dep = unh_dep_tot1 +h_dep_tot1
print(total1_dep)
# Out:
# 7
# 16
# 23

# %%
unh_anx_tot1 = 0
h_anx_tot1 = 0

for i in range(len(df_merged_1['total_gad_score'].values)):
  if df_merged_1['total_gad_score'].values[i] >8:
    unh_anx_tot1 +=1
  else:
    h_anx_tot1 +=1

# %%
print(unh_anx_tot1)
print(h_anx_tot1)
total1_anx = unh_anx_tot1 +h_anx_tot1
print(total1_anx)
# Out:
# 5
# 18
# 23

# %% [markdown]
# ## Set B

# %%
df_merged_2 = pd.read_csv('df_set2_final.csv')

# %%
emo_setb = ['Sad','Neutral','Angry','Neutral','Angry','Happy', 'Angry', 'Happy','Sad','Happy','Angry','Happy','Sad','Happy','Sad','Neutral','Sad','Angry','Neutral', 'Happy','Neutral','Sad','Angry','Sad','Neutral']

# %%
emotions = ['Happy', 'Sad', 'Angry', 'Neutral']
dfs2 = []
for j in emotions:
  temp = {}
  temp['Rec_Session_Id'] = list(df_merged_2['Rec_Session_Id'].values)
  temp['total_gad_score'] = list(df_merged_2['total_gad_score'].values)
  temp['total_phq_score'] = list(df_merged_2['total_phq_score'].values)
  temp['total_pss_score'] = list(df_merged_2['total_pss_score'].values)
  temp['total_panas_pos'] = list(df_merged_2['total_panas_pos'].values)
  temp['total_panas_neg'] = list(df_merged_2['total_panas_neg'].values)
  temp['total_fluency_score'] = list(df_merged_2['total_fluency_score'].values)

  for i in range(len(emo_setb)):
    if emo_setb[i] == j:
      # temp = {}
      temp[f'q{i+1}_val_setb'] = list(df_merged_2[f'q{i+1}_val_setb'].values)
      temp[f'q{i+1}_arous_setb'] = list(df_merged_2[f'q{i+1}_arous_setb'].values)
      temp[f'rt{i+1}b'] = list(df_merged_2[f'rt{i+1}a'].values)

  globals()[f'df2_{j}'] = pd.DataFrame.from_dict(temp)
  dfs2.append(globals()[f'df2_{j}'] )

# %%
unh_dep_tot2 = 0
h_dep_tot2 = 0

for i in range(len(df_merged_2['total_phq_score'].values)):
  if df_merged_2['total_phq_score'].values[i] >9:
    unh_dep_tot2 +=1
  else:
    h_dep_tot2 +=1

# %%
print(unh_dep_tot2)
print(h_dep_tot2)
total2_dep = unh_dep_tot2 +h_dep_tot2
print(total2_dep)
# Out:
# 6
# 20
# 26

# %%
unh_anx_tot2 = 0
h_anx_tot2 = 0

for i in range(len(df_merged_2['total_gad_score'].values)):
  if df_merged_2['total_gad_score'].values[i] >8:
    unh_anx_tot2 +=1
  else:
    h_anx_tot2 +=1

# %%
print(unh_anx_tot2)
print(h_anx_tot2)
total2_anx = unh_anx_tot2 +h_anx_tot2
print(total2_anx)
# Out:
# 8
# 18
# 26

# %% [markdown]
# ## Set C

# %%
df_merged_3 = pd.read_csv('df_set3_final.csv')

# %%
emo_setc = ['Neutral',
'Happy',
'Sad',
'Happy',
'Angry',
'Happy',
'Angry',
'Sad',
'Happy',
'Neutral',
'Happy',
'Sad',
'Sad',
'Neutral',
'Angry',
'Sad',
'Neutral',
'Angry',
'Happy',
'Neutral',
'Sad',
'Happy',
'Angry',
'Neutral',
'Angry']

# %%
emotions = ['Happy', 'Sad', 'Angry', 'Neutral']
dfs3 = []
for j in emotions:
  temp = {}
  temp['Rec_Session_Id'] = list(df_merged_3['Rec_Session_Id'].values)
  temp['total_gad_score'] = list(df_merged_3['total_gad_score'].values)
  temp['total_phq_score'] = list(df_merged_3['total_phq_score'].values)
  temp['total_pss_score'] = list(df_merged_3['total_pss_score'].values)
  temp['total_panas_pos'] = list(df_merged_3['total_panas_pos'].values)
  temp['total_panas_neg'] = list(df_merged_3['total_panas_neg'].values)
  temp['total_fluency_score'] = list(df_merged_3['total_fluency_score'].values)

  for i in range(len(emo_setc)):
    if emo_setc[i] == j:
      # temp = {}
      temp[f'q{i+1}_val_setc'] = list(df_merged_3[f'q{i+1}_val_setc'].values)
      temp[f'q{i+1}_arous_setc'] = list(df_merged_3[f'q{i+1}_arous_setc'].values)
      temp[f'rt{i+1}c'] = list(df_merged_3[f'rt{i+1}a'].values)

  globals()[f'df3_{j}'] = pd.DataFrame.from_dict(temp)
  dfs3.append(globals()[f'df3_{j}'] )

# %%
unh_dep_tot3 = 0
h_dep_tot3 = 0

for i in range(len(df_merged_3['total_phq_score'].values)):
  if df_merged_3['total_phq_score'].values[i] >9:
    unh_dep_tot3 +=1
  else:
    h_dep_tot3 +=1

# %%
print(unh_dep_tot3)
print(h_dep_tot3)
total3_dep = unh_dep_tot3 +h_dep_tot3
print(total3_dep)
# Out:
# 5
# 19
# 24

# %%
unh_anx_tot3 = 0
h_anx_tot3 = 0

for i in range(len(df_merged_3['total_gad_score'].values)):
  if df_merged_3['total_gad_score'].values[i] >8:
    unh_anx_tot3 +=1
  else:
    h_anx_tot3 +=1

# %%
print(unh_anx_tot3)
print(h_anx_tot3)
total3_anx = unh_anx_tot3 +h_anx_tot3
print(total3_anx)
# Out:
# 3
# 21
# 24

# %% [markdown]
# ## Set D

# %%
df_merged_4 = pd.read_csv('df_set4_final.csv')

# %%
emo_setd = ['Angry',
'Sad',
'Happy',
'Sad',
'Neutral',
'Happy',
'Angry',
'Sad',
'Angry',
'Neutral',
'Sad',
'Neutral',
'Sad',
'Happy',
'Angry',
'Happy',
'Sad',
'Neutral',
'Angry',
'Happy',
'Neutral',
'Angry',
'Happy',
'Neutral',
'Angry',]

# %%
emotions = ['Happy', 'Sad', 'Angry', 'Neutral']
dfs4 = []
for j in emotions:
  temp = {}
  temp['Rec_Session_Id'] = list(df_merged_4['Rec_Session_Id'].values)
  temp['total_gad_score'] = list(df_merged_4['total_gad_score'].values)
  temp['total_phq_score'] = list(df_merged_4['total_phq_score'].values)
  temp['total_pss_score'] = list(df_merged_4['total_pss_score'].values)
  temp['total_panas_pos'] = list(df_merged_4['total_panas_pos'].values)
  temp['total_panas_neg'] = list(df_merged_4['total_panas_neg'].values)
  temp['total_fluency_score'] = list(df_merged_4['total_fluency_score'].values)

  for i in range(len(emo_setd)):
    if emo_setd[i] == j:
      # temp = {}
      temp[f'q{i+1}_val_setd'] = list(df_merged_4[f'q{i+1}_val_setd'].values)
      temp[f'q{i+1}_arous_setd'] = list(df_merged_4[f'q{i+1}_arous_setd'].values)
      temp[f'rt{i+1}d'] = list(df_merged_4[f'rt{i+1}a'].values)

  globals()[f'df4_{j}'] = pd.DataFrame.from_dict(temp)
  dfs4.append(globals()[f'df4_{j}'] )

# %%
unh_dep_tot4 = 0
h_dep_tot4 = 0

for i in range(len(df_merged_4['total_phq_score'].values)):
  if df_merged_4['total_phq_score'].values[i] >9:
    unh_dep_tot4 +=1
  else:
    h_dep_tot4 +=1

# %%
print(unh_dep_tot4)
print(h_dep_tot4)
total4_dep = unh_dep_tot4 +h_dep_tot4
print(total4_dep)
# Out:
# 8
# 16
# 24

# %%
unh_anx_tot4 = 0
h_anx_tot4 = 0

for i in range(len(df_merged_4['total_gad_score'].values)):
  if df_merged_4['total_gad_score'].values[i] >8:
    unh_anx_tot4 +=1
  else:
    h_anx_tot4 +=1

# %%
print(unh_anx_tot4)
print(h_anx_tot4)
total4_anx = unh_anx_tot4 +h_anx_tot4
print(total4_anx)
# Out:
# 6
# 18
# 24

# %%
h_anx_tot4+h_anx_tot3+h_anx_tot2+h_anx_tot1
# Out:
# 75

# %% [markdown]
# # Violin Plot (PHQ)

# %%
# 2 arrays - healthy unhealthy, each has ratings first for all happy, sad, angry and then neutral

# %%
h_hap_val = []
h_sad_val = []
h_ang_val = []
h_neu_val = []

unh_hap_val = []
unh_sad_val = []
unh_ang_val = []
unh_neu_val = []

# ________________________________________________________

h_hap_arous = []
h_sad_arous = []
h_ang_arous = []
h_neu_arous = []

unh_hap_arous = []
unh_sad_arous = []
unh_ang_arous = []
unh_neu_arous = []

emotions = ["Happy", "Sad", "Angry", "Neutral"]

# %%
val_healthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])
val_unhealthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])
arous_healthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])
arous_unhealthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])

# %% [markdown]
# ### Set A

# %%
category = ['val', 'arous']
seta_dep = {}
for i in range(len(emotions)):
  for j in category:

    unh_dep_avg = 0
    h_dep_avg = 0

    unh_dep_tot = 0
    h_dep_tot = 0

    for col in dfs[i]:
      for k in range(len(dfs[i]['total_phq_score'])):
        if dfs[i]['total_phq_score'][k] > 9:
          if j in dfs[i][col].name:

            unh_dep_tot +=1
            unh_dep_avg += dfs[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs[i][col][k])




        else:
          if j in dfs[i][col].name:
            h_dep_tot +=1
            h_dep_avg += dfs[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    seta_dep[f'seta_{emotions[i]}_avg_{j}_sev_dep'] = unh_dep_avg/unh_dep_tot
    seta_dep[f'seta_{emotions[i]}_avg_{j}_non_dep'] = h_dep_avg/h_dep_tot
# Out:
# <ipython-input-112-095bb115ebac>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-112-095bb115ebac>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# <ipython-input-112-095bb115ebac>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# <ipython-input-112-095bb115ebac>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Set B

# %%
category = ['val', 'arous']
setb_dep = {}
for i in range(len(emotions)):
  for j in category:

    unh_dep_avg = 0
    h_dep_avg = 0

    unh_dep_tot = 0
    h_dep_tot = 0

    for col in dfs2[i]:
      for k in range(len(dfs2[i]['total_phq_score'])):
        if dfs2[i]['total_phq_score'][k] > 9:
          if j in dfs2[i][col].name:

            unh_dep_tot +=1
            unh_dep_avg += dfs2[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs2[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs2[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs2[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs2[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs2[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs2[i][col][k])




        elif dfs2[i]['total_phq_score'][k] <= 9:
          if j in dfs2[i][col].name:
            h_dep_tot +=1
            h_dep_avg += dfs2[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs2[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs2[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs2[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs2[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs2[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    setb_dep[f'setb_{emotions[i]}_avg_{j}_sev_dep'] = unh_dep_avg/unh_dep_tot
    setb_dep[f'setb_{emotions[i]}_avg_{j}_non_dep'] = h_dep_avg/h_dep_tot
# Out:
# <ipython-input-113-3a15b2c3cdf2>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# <ipython-input-113-3a15b2c3cdf2>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-113-3a15b2c3cdf2>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-113-3a15b2c3cdf2>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Set C

# %%
category = ['val', 'arous']
setc_dep = {}
for i in range(len(emotions)):
  for j in category:

    unh_dep_avg = 0
    h_dep_avg = 0

    unh_dep_tot = 0
    h_dep_tot = 0

    for col in dfs3[i]:
      for k in range(len(dfs3[i]['total_phq_score'])):
        if dfs3[i]['total_phq_score'][k] > 9:
          if j in dfs3[i][col].name:

            unh_dep_tot +=1
            unh_dep_avg += dfs3[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs3[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs3[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs3[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs3[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs3[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs3[i][col][k])




        elif dfs3[i]['total_phq_score'][k] <= 9:
          if j in dfs3[i][col].name:
            h_dep_tot +=1
            h_dep_avg += dfs3[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs3[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs3[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs3[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs3[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs3[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    setc_dep[f'setc_{emotions[i]}_avg_{j}_sev_dep'] = unh_dep_avg/unh_dep_tot
    setc_dep[f'setc_{emotions[i]}_avg_{j}_non_dep'] = h_dep_avg/h_dep_tot
# Out:
# <ipython-input-114-db870f2b2126>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-114-db870f2b2126>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# <ipython-input-114-db870f2b2126>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-114-db870f2b2126>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Set D

# %%
category = ['val', 'arous']
setd_dep = {}
for i in range(len(emotions)):
  for j in category:

    unh_dep_avg = 0
    h_dep_avg = 0

    unh_dep_tot = 0
    h_dep_tot = 0

    for col in dfs4[i]:
      for k in range(len(dfs4[i]['total_phq_score'])):
        if dfs4[i]['total_phq_score'][k] > 9:
          if j in dfs4[i][col].name:

            unh_dep_tot +=1
            unh_dep_avg += dfs4[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs4[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs4[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs4[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs4[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs4[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs4[i][col][k])




        elif dfs4[i]['total_phq_score'][k] <= 9:
          if j in dfs4[i][col].name:
            h_dep_tot +=1
            h_dep_avg += dfs4[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs4[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs4[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs4[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs4[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs4[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    setd_dep[f'setd_{emotions[i]}_avg_{j}_sev_dep'] = unh_dep_avg/unh_dep_tot
    setd_dep[f'setd_{emotions[i]}_avg_{j}_non_dep'] = h_dep_avg/h_dep_tot
# Out:
# <ipython-input-115-9f3de42fbb44>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# <ipython-input-115-9f3de42fbb44>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-115-9f3de42fbb44>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-115-9f3de42fbb44>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Violin Plots

# %%
# Sample data generation
np.random.seed(10)

# Combine both datasets (assuming val_healthy_data and val_unhealthy_data are defined)
combined_data = pd.concat([val_healthy_data, val_unhealthy_data])

# Plot
plt.figure(figsize=(4.2, 3))
sns.violinplot(data=combined_data, x='Category', y='Rating', hue='Emotion', split=False, inner='box',fill = False, linewidth=0.8, width=0.7, palette = 'colorblind')
plt.xlabel('Category')
plt.ylabel('PHQ-9 Rating')
plt.title('Valence Ratings across Emotions')

# Set y-axis ticks
plt.yticks(np.arange(1, 6, 1))

plt.tight_layout()

# Place the legend outside the plot
plt.legend(title='Emotion', bbox_to_anchor=(1.05, 1), loc='upper left')

# Save the figure as PDF
plt.savefig('Valence_Violin_no_fill_phq.pdf', bbox_inches='tight')
plt.show()

# %%
import seaborn as sns

# Sample data generation
np.random.seed(10)

# Combine both datasets (assuming val_healthy_data and val_unhealthy_data are defined)
combined_data = pd.concat([val_healthy_data, val_unhealthy_data])

# Plot
plt.figure(figsize=(4.2, 3))
sns.boxplot(data=combined_data, x='Category', y='Rating', hue='Emotion', palette='colorblind', linewidth=0.7, width=0.7)
plt.xlabel('Category')
plt.ylabel('PHQ-9 Rating')
plt.title('Valence Ratings across Emotions')

# Set y-axis ticks
plt.yticks(np.arange(1, 6, 1))

plt.tight_layout()

# Place the legend outside the plot
plt.legend(title='Emotion', bbox_to_anchor=(1.05, 1), loc='upper left')

# Save the figure as PDF
plt.savefig('Valence_Boxplot_no_fill_phq.pdf', bbox_inches='tight')
plt.show()

# %%
# Sample data generation
np.random.seed(0)

# Combine both datasets
combined_data = pd.concat([arous_healthy_data, arous_unhealthy_data])

# Plot
plt.figure(figsize=(5.5, 3))
sns.violinplot(data=combined_data, x='Category', y='Rating', hue='Emotion', split=False, inner='box', fill = False, linewidth=0.8, width=0.7, palette = 'colorblind')
plt.xlabel('Category')
plt.ylabel('PHQ-9 Rating')
plt.title('Arousal Ratings across Emotions')
plt.legend(title='Emotion')

# Set y-axis ticks
plt.yticks(np.arange(1, 6, 1))
plt.legend(title='Emotion', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()

# Save the figure as PDF
plt.savefig('Arousal_Violin_no_fill_phq.pdf', bbox_inches='tight')
plt.show()

# %%
import seaborn as sns

# Sample data generation
np.random.seed(0)

# Combine both datasets
combined_data = pd.concat([arous_healthy_data, arous_unhealthy_data])

# Plot
plt.figure(figsize=(5.5, 3))
sns.boxplot(data=combined_data, x='Category', y='Rating', hue='Emotion', palette='colorblind', linewidth=0.7, width=0.7)
plt.xlabel('Category')
plt.ylabel('PHQ-9 Rating')
plt.title('Arousal Ratings across Emotions')
plt.legend(title='Emotion')

# Set y-axis ticks
plt.yticks(np.arange(1, 6, 1))
plt.legend(title='Emotion', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()

# Save the figure as PDF
plt.savefig('Arousal_Boxplot_fill_phq.pdf', bbox_inches='tight')
plt.show()

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# np.random.seed(0)
# data = pd.DataFrame({
#     'Emotion': np.random.choice(['Happy', 'Sad', 'Angry', 'Neutral'], size=200),
#     'phq9_score': np.random.randint(0, 20, size=200),  # Assuming PHQ-9 scores are integers
#     'Rating': np.random.randint(1, 5, size=200),  # Assuming ratings are integers in the range 1-5
#     'Participant Group': np.random.choice(['Healthy', 'Non-Healthy'], size=200)
# })

# # Filtering healthy and non-healthy participants based on PHQ-9 score
# healthy = data[data['phq9_score'] < 9]
# non_healthy = data[data['phq9_score'] >= 9]

# # Creating separate plots for valence and arousal ratings
# fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # Adjust the figure size as needed

# # Valence Ratings
# sns.violinplot(x='Participant Group', y='Rating', hue='Emotion', data=healthy, ax=axs[0], palette='colorblind')
# sns.violinplot(x='Participant Group', y='Rating', hue='Emotion', data=non_healthy, ax=axs[1], palette='colorblind')

# # Adding labels and titles for valence ratings
# axs[0].set_title('Valence Ratings')
# axs[1].set_title('Arousal Ratings')
# axs[0].set_xlabel('Participant Group')
# axs[1].set_xlabel('Participant Group')
# axs[0].set_ylabel('Rating')
# axs[1].set_ylabel('Rating')

# # Remove legend from the plots
# axs[0].get_legend().remove()
# axs[1].get_legend().remove()

# # Create a common legend
# handles, labels = axs[0].get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center')

# # Adjust layout
# plt.tight_layout(rect=[0, 0, 1.5, 0.7])

# # Save the figure as PDF
# plt.savefig('violin_plots.pdf', bbox_inches='tight')

# # Show the plots
# plt.show()

# %% [markdown]
# # Standard Deviation (PHQ)

# %% [markdown]
# Cumulative is being calculated directly

# %%
category = ['val', 'arous']
all_sets_std_dep = {}
for i in range(len(emotions)):
  for j in category:

    unh_dep_values = []
    h_dep_values = []

    for col in dfs[i]:
      for k in range(len(dfs[i]['total_phq_score'])):
        if dfs[i]['total_phq_score'][k] > 9:
          if j in dfs[i][col].name:
            unh_dep_values.append(dfs[i][col][k])

        else:
          if j in dfs[i][col].name:
            h_dep_values.append(dfs[i][col][k])

    for col in dfs2[i]:
      for k in range(len(dfs2[i]['total_phq_score'])):
        if dfs2[i]['total_phq_score'][k] > 9:
          if j in dfs2[i][col].name:
            unh_dep_values.append(dfs2[i][col][k])

        else:
          if j in dfs2[i][col].name:
            h_dep_values.append(dfs2[i][col][k])


    for col in dfs3[i]:
      for k in range(len(dfs3[i]['total_phq_score'])):
        if dfs3[i]['total_phq_score'][k] > 9:
          if j in dfs3[i][col].name:
            unh_dep_values.append(dfs3[i][col][k])

        else:
          if j in dfs3[i][col].name:
            h_dep_values.append(dfs3[i][col][k])


    for col in dfs4[i]:
      for k in range(len(dfs4[i]['total_phq_score'])):
        if dfs4[i]['total_phq_score'][k] > 9:
          if j in dfs4[i][col].name:
            unh_dep_values.append(dfs4[i][col][k])

        else:
          if j in dfs4[i][col].name:
            h_dep_values.append(dfs4[i][col][k])

    all_sets_std_dep[f'all_sets_{emotions[i]}_std_dev_{j}_sev_dep'] = np.std(unh_dep_values) if unh_dep_values else 0
    all_sets_std_dep[f'all_sets_{emotions[i]}_std_dev_{j}_non_dep'] = np.std(h_dep_values) if h_dep_values else 0

# %%
all_sets_std_dep
# Out:
# {'all_sets_Happy_std_dev_val_sev_dep': 0.9224386691049428,
#  'all_sets_Happy_std_dev_val_non_dep': 0.884503060156569,
#  'all_sets_Happy_std_dev_arous_sev_dep': 1.1472034556615336,
#  'all_sets_Happy_std_dev_arous_non_dep': 1.077424395427653,
#  'all_sets_Sad_std_dev_val_sev_dep': 0.8908585858409114,
#  'all_sets_Sad_std_dev_val_non_dep': 1.0208296355636726,
#  'all_sets_Sad_std_dev_arous_sev_dep': 0.988444899635742,
#  'all_sets_Sad_std_dev_arous_non_dep': 1.041556446808735,
#  'all_sets_Angry_std_dev_val_sev_dep': 1.1061150400641149,
#  'all_sets_Angry_std_dev_val_non_dep': 1.0925610865725308,
#  'all_sets_Angry_std_dev_arous_sev_dep': 1.085348725543119,
#  'all_sets_Angry_std_dev_arous_non_dep': 1.126178804751853,
#  'all_sets_Neutral_std_dev_val_sev_dep': 0.977522225209792,
#  'all_sets_Neutral_std_dev_val_non_dep': 0.9045021376607247,
#  'all_sets_Neutral_std_dev_arous_sev_dep': 0.8941494172666046,
#  'all_sets_Neutral_std_dev_arous_non_dep': 1.0074150262498278}

# %% [markdown]
# # Standard Deviation (GAD)

# %% [markdown]
# Cumulative is being calculated directly

# %%
category = ['val', 'arous']
all_sets_std_anx = {}
for i in range(len(emotions)):
  for j in category:

    unh_anx_values = []
    h_anx_values = []

    for col in dfs[i]:
      for k in range(len(dfs[i]['total_gad_score'])):
        if dfs[i]['total_gad_score'][k] > 8:
          if j in dfs[i][col].name:
            unh_anx_values.append(dfs[i][col][k])

        else:
          if j in dfs[i][col].name:
            h_anx_values.append(dfs[i][col][k])

    for col in dfs2[i]:
      for k in range(len(dfs2[i]['total_gad_score'])):
        if dfs2[i]['total_gad_score'][k] > 8:
          if j in dfs2[i][col].name:
            unh_anx_values.append(dfs2[i][col][k])

        else:
          if j in dfs2[i][col].name:
            h_anx_values.append(dfs2[i][col][k])


    for col in dfs3[i]:
      for k in range(len(dfs3[i]['total_gad_score'])):
        if dfs3[i]['total_gad_score'][k] > 8:
          if j in dfs3[i][col].name:
            unh_anx_values.append(dfs3[i][col][k])

        else:
          if j in dfs3[i][col].name:
            h_anx_values.append(dfs3[i][col][k])


    for col in dfs4[i]:
      for k in range(len(dfs4[i]['total_gad_score'])):
        if dfs4[i]['total_gad_score'][k] > 8:
          if j in dfs4[i][col].name:
            unh_anx_values.append(dfs4[i][col][k])

        else:
          if j in dfs4[i][col].name:
            h_anx_values.append(dfs4[i][col][k])

    all_sets_std_anx[f'all_sets_{emotions[i]}_std_dev_{j}_sev_anx'] = np.std(unh_anx_values) if unh_anx_values else 0
    all_sets_std_anx[f'all_sets_{emotions[i]}_std_dev_{j}_non_anx'] = np.std(h_anx_values) if h_anx_values else 0

# %%
all_sets_std_anx
# Out:
# {'all_sets_Happy_std_dev_val_sev_anx': 0.925896295822207,
#  'all_sets_Happy_std_dev_val_non_anx': 0.8818889911517219,
#  'all_sets_Happy_std_dev_arous_sev_anx': 1.0503379820530199,
#  'all_sets_Happy_std_dev_arous_non_anx': 1.1048217016639283,
#  'all_sets_Sad_std_dev_val_sev_anx': 0.9250206837180035,
#  'all_sets_Sad_std_dev_val_non_anx': 1.0070066463818685,
#  'all_sets_Sad_std_dev_arous_sev_anx': 0.9934479228979263,
#  'all_sets_Sad_std_dev_arous_non_anx': 1.0362410751281506,
#  'all_sets_Angry_std_dev_val_sev_anx': 1.14996141593492,
#  'all_sets_Angry_std_dev_val_non_anx': 1.0810086489147146,
#  'all_sets_Angry_std_dev_arous_sev_anx': 1.1294356416923708,
#  'all_sets_Angry_std_dev_arous_non_anx': 1.1120640226769969,
#  'all_sets_Neutral_std_dev_val_sev_anx': 0.9392546892636445,
#  'all_sets_Neutral_std_dev_val_non_anx': 0.9155876940415445,
#  'all_sets_Neutral_std_dev_arous_sev_anx': 0.9569562987779495,
#  'all_sets_Neutral_std_dev_arous_non_anx': 0.9840642562199075}

# %% [markdown]
# # Violin Plots (GAD)

# %%
h_hap_val = []
h_sad_val = []
h_ang_val = []
h_neu_val = []

unh_hap_val = []
unh_sad_val = []
unh_ang_val = []
unh_neu_val = []

# ________________________________________________________

h_hap_arous = []
h_sad_arous = []
h_ang_arous = []
h_neu_arous = []

unh_hap_arous = []
unh_sad_arous = []
unh_ang_arous = []
unh_neu_arous = []

emotions = ["Happy", "Sad", "Angry", "Neutral"]

# %%
val_healthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])
val_unhealthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])
arous_healthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])
arous_unhealthy_data = pd.DataFrame(columns=['Emotion', 'Rating', 'Category'])

# %% [markdown]
# ### Set A

# %%
category = ['val', 'arous']
seta_anx = {}
for i in range(len(emotions)):
  for j in category:

    unh_anx_avg = 0
    h_anx_avg = 0

    unh_anx_tot = 0
    h_anx_tot = 0

    for col in dfs[i]:
      for k in range(len(dfs[i]['total_gad_score'])):
        if dfs[i]['total_gad_score'][k] > 8:
          if j in dfs[i][col].name:

            unh_anx_tot +=1
            unh_anx_avg += dfs[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs[i][col][k])




        elif dfs[i]['total_gad_score'][k] <= 8:
          if j in dfs[i][col].name:
            h_anx_tot +=1
            h_anx_avg += dfs[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    seta_anx[f'seta_{emotions[i]}_avg_{j}_sev_anx'] = unh_anx_avg/unh_anx_tot
    seta_anx[f'seta_{emotions[i]}_avg_{j}_non_anx'] = h_anx_avg/h_anx_tot
# Out:
# <ipython-input-50-f52e1128abe1>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-50-f52e1128abe1>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-50-f52e1128abe1>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-50-f52e1128abe1>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Set B

# %%
category = ['val', 'arous']
setb_anx = {}
for i in range(len(emotions)):
  for j in category:

    unh_anx_avg = 0
    h_anx_avg = 0

    unh_anx_tot = 0
    h_anx_tot = 0

    for col in dfs2[i]:
      for k in range(len(dfs2[i]['total_gad_score'])):
        if dfs2[i]['total_gad_score'][k] > 8:
          if j in dfs2[i][col].name:

            unh_anx_tot +=1
            unh_anx_avg += dfs2[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs2[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs2[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs2[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs2[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs2[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs2[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs2[i][col][k])




        elif dfs2[i]['total_gad_score'][k] <= 8:
          if j in dfs2[i][col].name:
            h_anx_tot +=1
            h_anx_avg += dfs2[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs2[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs2[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs2[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs2[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs2[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs2[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs2[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    setb_anx[f'setb_{emotions[i]}_avg_{j}_sev_anx'] = unh_anx_avg/unh_anx_tot
    setb_anx[f'setb_{emotions[i]}_avg_{j}_non_anx'] = h_anx_avg/h_anx_tot
# Out:
# <ipython-input-51-54bc485b8b9f>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# <ipython-input-51-54bc485b8b9f>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-51-54bc485b8b9f>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-51-54bc485b8b9f>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Set C

# %%
category = ['val', 'arous']
setc_anx = {}
for i in range(len(emotions)):
  for j in category:

    unh_anx_avg = 0
    h_anx_avg = 0

    unh_anx_tot = 0
    h_anx_tot = 0

    for col in dfs3[i]:
      for k in range(len(dfs3[i]['total_gad_score'])):
        if dfs3[i]['total_gad_score'][k] > 8:
          if j in dfs3[i][col].name:

            unh_anx_tot +=1
            unh_anx_avg += dfs3[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs3[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs3[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs3[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs3[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs3[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs3[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs3[i][col][k])




        elif dfs3[i]['total_gad_score'][k] <= 8:
          if j in dfs3[i][col].name:
            h_anx_tot +=1
            h_anx_avg += dfs3[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs3[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs3[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs3[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs3[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs3[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs3[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs3[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    setc_anx[f'setc_{emotions[i]}_avg_{j}_sev_anx'] = unh_anx_avg/unh_anx_tot
    setc_anx[f'setc_{emotions[i]}_avg_{j}_non_anx'] = h_anx_avg/h_anx_tot
# Out:
# <ipython-input-52-08e73befa91c>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-52-08e73befa91c>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-52-08e73befa91c>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-52-08e73befa91c>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Set D

# %%
category = ['val', 'arous']
setd_anx = {}
for i in range(len(emotions)):
  for j in category:

    unh_anx_avg = 0
    h_anx_avg = 0

    unh_anx_tot = 0
    h_anx_tot = 0

    for col in dfs4[i]:
      for k in range(len(dfs4[i]['total_gad_score'])):
        if dfs4[i]['total_gad_score'][k] > 8:
          if j in dfs4[i][col].name:

            unh_anx_tot +=1
            unh_anx_avg += dfs4[i][col][k]
            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_val.append(dfs4[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_val.append(dfs4[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_val.append(dfs4[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_val.append(dfs4[i][col][k])


            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_hap_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_sad_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_ang_arous.append(dfs4[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Unealthy', 'Rating' : dfs4[i][col][k]}
              arous_unhealthy_data = arous_unhealthy_data.append(new_row, ignore_index=True)
              unh_neu_arous.append(dfs4[i][col][k])




        elif dfs4[i]['total_gad_score'][k] <= 8:
          if j in dfs4[i][col].name:
            h_anx_tot +=1
            h_anx_avg += dfs4[i][col][k]

            if j=='val' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_hap_val.append(dfs4[i][col][k])

            elif j=='val' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_sad_val.append(dfs4[i][col][k])

            elif j=='val' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_ang_val.append(dfs4[i][col][k])

            elif j == 'val' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
              h_neu_val.append(dfs4[i][col][k])




            if j=='arous' and i == 0:
              new_row = {'Emotion' : 'Happy', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_hap_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 1:
              new_row = {'Emotion' : 'Sad', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_sad_arous.append(dfs4[i][col][k])

            elif j=='arous' and i == 2:
              new_row = {'Emotion' : 'Angry', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)
              h_ang_arous.append(dfs4[i][col][k])

            elif j == 'arous' and i ==3:
              new_row = {'Emotion' : 'Neutral', 'Category' : 'Healthy', 'Rating' : dfs4[i][col][k]}
              arous_healthy_data = arous_healthy_data.append(new_row, ignore_index=True)


    setd_anx[f'setd_{emotions[i]}_avg_{j}_sev_anx'] = unh_anx_avg/unh_anx_tot
    setd_anx[f'setd_{emotions[i]}_avg_{j}_non_anx'] = h_anx_avg/h_anx_tot
# Out:
# <ipython-input-53-8a0de115e2cb>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# <ipython-input-53-8a0de115e2cb>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-53-8a0de115e2cb>:70: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_healthy_data = val_healthy_data.append(new_row, ignore_index=True)
# <ipython-input-53-8a0de115e2cb>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val_unhealthy_data = val_unhealthy_data.append(new_row, ignore_index=True)
# ...

# %% [markdown]
# ### Violin Plots

# %%
# Sample data generation
np.random.seed(10)

# Combine both datasets (assuming val_healthy_data and val_unhealthy_data are defined)
combined_data = pd.concat([val_healthy_data, val_unhealthy_data])

# Plot
plt.figure(figsize=(4.2, 3))
sns.violinplot(data=combined_data, x='Category', y='Rating', hue='Emotion', split=False, inner='box', fill=False, linewidth=0.7, width=0.7, palette='colorblind')
plt.xlabel('Category')
plt.ylabel('Ratings')
plt.title('Valence Ratings across Emotions (GAD categorization)')

# Set y-axis ticks
plt.yticks(np.arange(1, 6, 1))

plt.tight_layout()

# Place the legend outside the plot
plt.legend(title='Emotion', bbox_to_anchor=(1.05, 1), loc='upper left')

# Save the figure as PDF
plt.savefig('Valence_Violin_no_fill_gad.pdf', bbox_inches='tight')
plt.show()

# %%
# Sample data generation
np.random.seed(0)

# Combine both datasets
combined_data = pd.concat([arous_healthy_data, arous_unhealthy_data])

# Plot
plt.figure(figsize=(5.5, 3))
sns.violinplot(data=combined_data, x='Category', y='Rating', hue='Emotion', split=False, fill=False, inner='box', linewidth=0.7, width=0.7, palette='colorblind')
plt.xlabel('Category')
plt.ylabel('Rating')
plt.title('Arousal Ratings across Emotions(GAD Categorization)')
plt.legend(title='Emotion')

# Set y-axis ticks
plt.yticks(np.arange(1, 6, 1))
plt.legend(title='Emotion', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()

# Save the figure as PDF
plt.savefig('Arousal_Violin_no_fill_gad.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Cumulative Tables (PHQ)

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_dep_tot1+h_dep_tot2+h_dep_tot3+h_dep_tot4), 'Unhealthy : %s' % str(unh_dep_tot1+unh_dep_tot2+unh_dep_tot3+unh_dep_tot4)])
myTable.title = 'Valence ~ Mean ~ All Sets'
# Averaging for all emeotions

# Add rows
myTable.add_row(["Happy", round((((setd_dep['setd_Happy_avg_val_non_dep'])*(h_dep_tot4)*(6)) + ((setc_dep['setc_Happy_avg_val_non_dep'])*(h_dep_tot3)*(7)) + ((setb_dep['setb_Happy_avg_val_non_dep'])*(h_dep_tot2)*(6)) + ((seta_dep['seta_Happy_avg_val_non_dep'])*(h_dep_tot1)*(6)))/((h_dep_tot4*6)+(h_dep_tot3*7)+(h_dep_tot2*6)+(h_dep_tot1*6)),2),
                 round((((setd_dep['setd_Happy_avg_val_sev_dep'])*(unh_dep_tot4)*(6)) + ((setc_dep['setc_Happy_avg_val_sev_dep'])*(unh_dep_tot3)*(7)) + ((setb_dep['setb_Happy_avg_val_sev_dep'])*(unh_dep_tot2)*(6)) + ((seta_dep['seta_Happy_avg_val_sev_dep'])*(unh_dep_tot1)*(6)))/((unh_dep_tot4*6)+(unh_dep_tot3*7)+(unh_dep_tot2*6)+(unh_dep_tot1*6)),2)])

myTable.add_row(["Sad", round((((setd_dep['setd_Sad_avg_val_non_dep'])*(h_dep_tot4)*(6)) + ((setc_dep['setc_Sad_avg_val_non_dep'])*(h_dep_tot3)*(6)) + ((setb_dep['setb_Sad_avg_val_non_dep'])*(h_dep_tot2)*(7)) + ((seta_dep['seta_Sad_avg_val_non_dep'])*(h_dep_tot1)*(6)))/(h_dep_tot4*(6)+h_dep_tot3*(6)+h_dep_tot2*(7)+h_dep_tot1*(6)),2),
                 round((((setd_dep['setd_Sad_avg_val_sev_dep'])*(unh_dep_tot4)*(6)) + ((setc_dep['setc_Sad_avg_val_sev_dep'])*(unh_dep_tot3)*(6)) + ((setb_dep['setb_Sad_avg_val_sev_dep'])*(unh_dep_tot2)*(7)) + ((seta_dep['seta_Sad_avg_val_sev_dep'])*(unh_dep_tot1)*(6)))/(unh_dep_tot4*(6)+unh_dep_tot3*(6)+unh_dep_tot2*(7)+unh_dep_tot1*(6)),2)])

myTable.add_row(["Angry", round((((setd_dep['setd_Angry_avg_val_non_dep'])*(h_dep_tot4)*(7)) + ((setc_dep['setc_Angry_avg_val_non_dep'])*(h_dep_tot3)*(6)) + ((setb_dep['setb_Angry_avg_val_non_dep'])*(h_dep_tot2)*(6)) + ((seta_dep['seta_Angry_avg_val_non_dep'])*(h_dep_tot1)*(6)))/(h_dep_tot4*(7)+h_dep_tot3*(6)+h_dep_tot2*(6)+h_dep_tot1*(6)),2),
                 round((((setd_dep['setd_Angry_avg_val_sev_dep'])*(unh_dep_tot4)*(7)) + ((setc_dep['setc_Angry_avg_val_sev_dep'])*(unh_dep_tot3)*(6)) + ((setb_dep['setb_Angry_avg_val_sev_dep'])*(unh_dep_tot2)*(6)) + ((seta_dep['seta_Angry_avg_val_sev_dep'])*(unh_dep_tot1)*(6)))/(unh_dep_tot4*(7)+unh_dep_tot3*(6)+unh_dep_tot2*(6)+unh_dep_tot1*(6)),2)])

myTable.add_row(["Neutral", round((((setd_dep['setd_Neutral_avg_val_non_dep'])*(h_dep_tot4)*(6)) + ((setc_dep['setc_Neutral_avg_val_non_dep'])*(h_dep_tot3)*(6)) + ((setb_dep['setb_Neutral_avg_val_non_dep'])*(h_dep_tot2)*(6)) + ((seta_dep['seta_Neutral_avg_val_non_dep'])*(h_dep_tot1)*(7)))/(h_dep_tot4*(6)+h_dep_tot3*(6)+h_dep_tot2*(6)+h_dep_tot1*(7)),2),
                 round((((setd_dep['setd_Neutral_avg_val_sev_dep'])*(unh_dep_tot4)*(6)) + ((setc_dep['setc_Neutral_avg_val_sev_dep'])*(unh_dep_tot3)*(6)) + ((setb_dep['setb_Neutral_avg_val_sev_dep'])*(unh_dep_tot2)*(6)) + ((seta_dep['seta_Neutral_avg_val_sev_dep'])*(unh_dep_tot1)*(7)))/(unh_dep_tot4*(6)+unh_dep_tot3*(6)+unh_dep_tot2*(6)+unh_dep_tot1*(7)),2)])
print('For Valence ~ Mean ~ All Sets')
print(myTable)
# Out:
# For Valence ~ Mean ~ All Sets
# +-----------------------------------------+
# |        Valence ~ Mean ~ All Sets        |
# +---------+--------------+----------------+
# | Emotion | Healthy : 71 | Unhealthy : 26 |
# +---------+--------------+----------------+
# |  Happy  |     3.79     |      3.86      |
# |   Sad   |     2.54     |      2.31      |
# |  Angry  |     2.17     |      2.27      |
# | Neutral |     3.17     |      2.86      |
# +---------+--------------+----------------+

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_dep_tot1+h_dep_tot2+h_dep_tot3+h_dep_tot4), 'Unhealthy : %s' % str(unh_dep_tot1+unh_dep_tot2+unh_dep_tot3+unh_dep_tot4)])
myTable.title = 'Arousal ~ Mean ~ All Sets'
# Averaging for all emeotions

# Add rows
myTable.add_row(["Happy", round((((setd_dep['setd_Happy_avg_arous_non_dep'])*(h_dep_tot4)*(6)) + ((setc_dep['setc_Happy_avg_arous_non_dep'])*(h_dep_tot3)*(7)) + ((setb_dep['setb_Happy_avg_arous_non_dep'])*(h_dep_tot2)*(6)) + ((seta_dep['seta_Happy_avg_arous_non_dep'])*(h_dep_tot1)*(6)))/((h_dep_tot4*6)+(h_dep_tot3*7)+(h_dep_tot2*6)+(h_dep_tot1*6)),2),
                 round((((setd_dep['setd_Happy_avg_arous_sev_dep'])*(unh_dep_tot4)*(6)) + ((setc_dep['setc_Happy_avg_arous_sev_dep'])*(unh_dep_tot3)*(7)) + ((setb_dep['setb_Happy_avg_arous_sev_dep'])*(unh_dep_tot2)*(6)) + ((seta_dep['seta_Happy_avg_arous_sev_dep'])*(unh_dep_tot1)*(6)))/((unh_dep_tot4*6)+(unh_dep_tot3*7)+(unh_dep_tot2*6)+(unh_dep_tot1*6)),2)])

myTable.add_row(["Sad", round((((setd_dep['setd_Sad_avg_arous_non_dep'])*(h_dep_tot4)*(6)) + ((setc_dep['setc_Sad_avg_arous_non_dep'])*(h_dep_tot3)*(6)) + ((setb_dep['setb_Sad_avg_arous_non_dep'])*(h_dep_tot2)*(7)) + ((seta_dep['seta_Sad_avg_arous_non_dep'])*(h_dep_tot1)*(6)))/(h_dep_tot4*(6)+h_dep_tot3*(6)+h_dep_tot2*(7)+h_dep_tot1*(6)),2),
                 round((((setd_dep['setd_Sad_avg_arous_sev_dep'])*(unh_dep_tot4)*(6)) + ((setc_dep['setc_Sad_avg_arous_sev_dep'])*(unh_dep_tot3)*(6)) + ((setb_dep['setb_Sad_avg_arous_sev_dep'])*(unh_dep_tot2)*(7)) + ((seta_dep['seta_Sad_avg_arous_sev_dep'])*(unh_dep_tot1)*(6)))/(unh_dep_tot4*(6)+unh_dep_tot3*(6)+unh_dep_tot2*(7)+unh_dep_tot1*(6)),2)])

myTable.add_row(["Angry", round((((setd_dep['setd_Angry_avg_arous_non_dep'])*(h_dep_tot4)*(7)) + ((setc_dep['setc_Angry_avg_arous_non_dep'])*(h_dep_tot3)*(6)) + ((setb_dep['setb_Angry_avg_arous_non_dep'])*(h_dep_tot2)*(6)) + ((seta_dep['seta_Angry_avg_arous_non_dep'])*(h_dep_tot1)*(6)))/(h_dep_tot4*(7)+h_dep_tot3*(6)+h_dep_tot2*(6)+h_dep_tot1*(6)),2),
                 round((((setd_dep['setd_Angry_avg_arous_sev_dep'])*(unh_dep_tot4)*(7)) + ((setc_dep['setc_Angry_avg_arous_sev_dep'])*(unh_dep_tot3)*(6)) + ((setb_dep['setb_Angry_avg_arous_sev_dep'])*(unh_dep_tot2)*(6)) + ((seta_dep['seta_Angry_avg_arous_sev_dep'])*(unh_dep_tot1)*(6)))/(unh_dep_tot4*(7)+unh_dep_tot3*(6)+unh_dep_tot2*(6)+unh_dep_tot1*(6)),2)])

myTable.add_row(["Neutral", round((((setd_dep['setd_Neutral_avg_arous_non_dep'])*(h_dep_tot4)*(6)) + ((setc_dep['setc_Neutral_avg_arous_non_dep'])*(h_dep_tot3)*(6)) + ((setb_dep['setb_Neutral_avg_arous_non_dep'])*(h_dep_tot2)*(6)) + ((seta_dep['seta_Neutral_avg_arous_non_dep'])*(h_dep_tot1)*(7)))/(h_dep_tot4*(6)+h_dep_tot3*(6)+h_dep_tot2*(6)+h_dep_tot1*(7)),2),
                 round((((setd_dep['setd_Neutral_avg_arous_sev_dep'])*(unh_dep_tot4)*(6)) + ((setc_dep['setc_Neutral_avg_arous_sev_dep'])*(unh_dep_tot3)*(6)) + ((setb_dep['setb_Neutral_avg_arous_sev_dep'])*(unh_dep_tot2)*(6)) + ((seta_dep['seta_Neutral_avg_arous_sev_dep'])*(unh_dep_tot1)*(7)))/(unh_dep_tot4*(6)+unh_dep_tot3*(6)+unh_dep_tot2*(6)+unh_dep_tot1*(7)),2)])
print('For Arousal ~ Mean ~ All Sets')
print(myTable)
# Out:
# For Arousal ~ Mean ~ All Sets
# +-----------------------------------------+
# |        Arousal ~ Mean ~ All Sets        |
# +---------+--------------+----------------+
# | Emotion | Healthy : 71 | Unhealthy : 26 |
# +---------+--------------+----------------+
# |  Happy  |     3.42     |      3.38      |
# |   Sad   |     2.2      |      2.2       |
# |  Angry  |     3.76     |      3.65      |
# | Neutral |     2.24     |      2.2       |
# +---------+--------------+----------------+

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_dep_tot1+h_dep_tot2+h_dep_tot3+h_dep_tot4), 'Unhealthy : %s' % str(unh_dep_tot1+unh_dep_tot2+unh_dep_tot3+unh_dep_tot4)])
myTable.title = 'Valence ~ Standard Deviation ~ All Sets [N = 97]'
# Add rows
# print(all_sets_std_dep.keys())
myTable.add_row(["Happy", round(all_sets_std_dep['all_sets_Happy_std_dev_val_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Happy_std_dev_val_sev_dep'],2)
                 ])
myTable.add_row(["Sad", round(all_sets_std_dep['all_sets_Sad_std_dev_val_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Sad_std_dev_val_sev_dep'],2)
                 ])
myTable.add_row(["Angry", round(all_sets_std_dep['all_sets_Angry_std_dev_val_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Angry_std_dev_val_sev_dep'],2)
                 ])
myTable.add_row(["Neutral", round(all_sets_std_dep['all_sets_Neutral_std_dev_val_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Neutral_std_dev_val_sev_dep'],2)
                 ])
print('Valence ~ Standard Deviation ~ All Sets [N=97]')
print(myTable)
# Out:
# Valence ~ Standard Deviation ~ All Sets [N=97]
# +--------------------------------------------------+
# | Valence ~ Standard Deviation ~ All Sets [N = 97] |
# +----------+-----------------+---------------------+
# | Emotion  |   Healthy : 71  |    Unhealthy : 26   |
# +----------+-----------------+---------------------+
# |  Happy   |       0.88      |         0.92        |
# |   Sad    |       1.02      |         0.89        |
# |  Angry   |       1.09      |         1.11        |
# | Neutral  |       0.9       |         0.98        |
# +----------+-----------------+---------------------+

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_dep_tot1+h_dep_tot2+h_dep_tot3+h_dep_tot4), 'Unhealthy : %s' % str(unh_dep_tot1+unh_dep_tot2+unh_dep_tot3+unh_dep_tot4)])
myTable.title = 'Arousal ~ Standard Deviation ~ All Sets [N = 97]'
# Add rows
# print(all_sets_std_dep.keys())
myTable.add_row(["Happy", round(all_sets_std_dep['all_sets_Happy_std_dev_arous_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Happy_std_dev_arous_sev_dep'],2)
                 ])
myTable.add_row(["Sad", round(all_sets_std_dep['all_sets_Sad_std_dev_arous_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Sad_std_dev_arous_sev_dep'],2)
                 ])
myTable.add_row(["Angry", round(all_sets_std_dep['all_sets_Angry_std_dev_arous_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Angry_std_dev_arous_sev_dep'],2)
                 ])
myTable.add_row(["Neutral", round(all_sets_std_dep['all_sets_Neutral_std_dev_arous_non_dep'],2),
                 round(all_sets_std_dep['all_sets_Neutral_std_dev_arous_sev_dep'],2)
                 ])
print('Arousal ~ Standard Deviation ~ All Sets [N=97]')
print(myTable)
# Out:
# Arousal ~ Standard Deviation ~ All Sets [N=97]
# +--------------------------------------------------+
# | Arousal ~ Standard Deviation ~ All Sets [N = 97] |
# +----------+-----------------+---------------------+
# | Emotion  |   Healthy : 71  |    Unhealthy : 26   |
# +----------+-----------------+---------------------+
# |  Happy   |       1.08      |         1.15        |
# |   Sad    |       1.04      |         0.99        |
# |  Angry   |       1.13      |         1.09        |
# | Neutral  |       1.01      |         0.89        |
# +----------+-----------------+---------------------+

# %% [markdown]
# # Cumulative Tables (GAD)

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_anx_tot1+h_anx_tot2+h_anx_tot3+h_anx_tot4), 'Unhealthy : %s' % str(unh_anx_tot1+unh_anx_tot2+unh_anx_tot3+unh_anx_tot4)])
myTable.title = 'Valence ~ Mean ~ All Sets'
# Averaging for all emeotions

# Add rows
myTable.add_row(["Happy", round((((setd_anx['setd_Happy_avg_val_non_anx'])*(h_anx_tot4)*(6)) + ((setc_anx['setc_Happy_avg_val_non_anx'])*(h_anx_tot3)*(7)) + ((setb_anx['setb_Happy_avg_val_non_anx'])*(h_anx_tot2)*(6)) + ((seta_anx['seta_Happy_avg_val_non_anx'])*(h_anx_tot1)*(6)))/((h_anx_tot4*6)+(h_anx_tot3*7)+(h_anx_tot2*6)+(h_anx_tot1*6)),2),
                 round((((setd_anx['setd_Happy_avg_val_sev_anx'])*(unh_anx_tot4)*(6)) + ((setc_anx['setc_Happy_avg_val_sev_anx'])*(unh_anx_tot3)*(7)) + ((setb_anx['setb_Happy_avg_val_sev_anx'])*(unh_anx_tot2)*(6)) + ((seta_anx['seta_Happy_avg_val_sev_anx'])*(unh_anx_tot1)*(6)))/((unh_anx_tot4*6)+(unh_anx_tot3*7)+(unh_anx_tot2*6)+(unh_anx_tot1*6)),2)])

myTable.add_row(["Sad", round((((setd_anx['setd_Sad_avg_val_non_anx'])*(h_anx_tot4)*(6)) + ((setc_anx['setc_Sad_avg_val_non_anx'])*(h_anx_tot3)*(6)) + ((setb_anx['setb_Sad_avg_val_non_anx'])*(h_anx_tot2)*(7)) + ((seta_anx['seta_Sad_avg_val_non_anx'])*(h_anx_tot1)*(6)))/(h_anx_tot4*(6)+h_anx_tot3*(6)+h_anx_tot2*(7)+h_anx_tot1*(6)),2),
                 round((((setd_anx['setd_Sad_avg_val_sev_anx'])*(unh_anx_tot4)*(6)) + ((setc_anx['setc_Sad_avg_val_sev_anx'])*(unh_anx_tot3)*(6)) + ((setb_anx['setb_Sad_avg_val_sev_anx'])*(unh_anx_tot2)*(7)) + ((seta_anx['seta_Sad_avg_val_sev_anx'])*(unh_anx_tot1)*(6)))/(unh_anx_tot4*(6)+unh_anx_tot3*(6)+unh_anx_tot2*(7)+unh_anx_tot1*(6)),2)])

myTable.add_row(["Angry", round((((setd_anx['setd_Angry_avg_val_non_anx'])*(h_anx_tot4)*(7)) + ((setc_anx['setc_Angry_avg_val_non_anx'])*(h_anx_tot3)*(6)) + ((setb_anx['setb_Angry_avg_val_non_anx'])*(h_anx_tot2)*(6)) + ((seta_anx['seta_Angry_avg_val_non_anx'])*(h_anx_tot1)*(6)))/(h_anx_tot4*(7)+h_anx_tot3*(6)+h_anx_tot2*(6)+h_anx_tot1*(6)),2),
                 round((((setd_anx['setd_Angry_avg_val_sev_anx'])*(unh_anx_tot4)*(7)) + ((setc_anx['setc_Angry_avg_val_sev_anx'])*(unh_anx_tot3)*(6)) + ((setb_anx['setb_Angry_avg_val_sev_anx'])*(unh_anx_tot2)*(6)) + ((seta_anx['seta_Angry_avg_val_sev_anx'])*(unh_anx_tot1)*(6)))/(unh_anx_tot4*(7)+unh_anx_tot3*(6)+unh_anx_tot2*(6)+unh_anx_tot1*(6)),2)])

myTable.add_row(["Neutral", round((((setd_anx['setd_Neutral_avg_val_non_anx'])*(h_anx_tot4)*(6)) + ((setc_anx['setc_Neutral_avg_val_non_anx'])*(h_anx_tot3)*(6)) + ((setb_anx['setb_Neutral_avg_val_non_anx'])*(h_anx_tot2)*(6)) + ((seta_anx['seta_Neutral_avg_val_non_anx'])*(h_anx_tot1)*(7)))/(h_anx_tot4*(6)+h_anx_tot3*(6)+h_anx_tot2*(6)+h_anx_tot1*(7)),2),
                 round((((setd_anx['setd_Neutral_avg_val_sev_anx'])*(unh_anx_tot4)*(6)) + ((setc_anx['setc_Neutral_avg_val_sev_anx'])*(unh_anx_tot3)*(6)) + ((setb_anx['setb_Neutral_avg_val_sev_anx'])*(unh_anx_tot2)*(6)) + ((seta_anx['seta_Neutral_avg_val_sev_anx'])*(unh_anx_tot1)*(7)))/(unh_anx_tot4*(6)+unh_anx_tot3*(6)+unh_anx_tot2*(6)+unh_anx_tot1*(7)),2)])
print('For Valence ~ Mean ~ All Sets')
print(myTable)
# Out:
# For Valence ~ Mean ~ All Sets
# +-----------------------------------------+
# |        Valence ~ Mean ~ All Sets        |
# +---------+--------------+----------------+
# | Emotion | Healthy : 75 | Unhealthy : 22 |
# +---------+--------------+----------------+
# |  Happy  |     3.77     |      3.96      |
# |   Sad   |     2.53     |      2.31      |
# |  Angry  |     2.21     |      2.16      |
# | Neutral |     3.17     |      2.79      |
# +---------+--------------+----------------+

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_anx_tot1+h_anx_tot2+h_anx_tot3+h_anx_tot4), 'Unhealthy : %s' % str(unh_anx_tot1+unh_anx_tot2+unh_anx_tot3+unh_anx_tot4)])
myTable.title = 'Arousal ~ Mean ~ All Sets'
# Averaging for all emeotions

# Add rows
myTable.add_row(["Happy", round((((setd_anx['setd_Happy_avg_arous_non_anx'])*(h_anx_tot4)*(6)) + ((setc_anx['setc_Happy_avg_arous_non_anx'])*(h_anx_tot3)*(7)) + ((setb_anx['setb_Happy_avg_arous_non_anx'])*(h_anx_tot2)*(6)) + ((seta_anx['seta_Happy_avg_arous_non_anx'])*(h_anx_tot1)*(6)))/((h_anx_tot4*6)+(h_anx_tot3*7)+(h_anx_tot2*6)+(h_anx_tot1*6)),2),
                 round((((setd_anx['setd_Happy_avg_arous_sev_anx'])*(unh_anx_tot4)*(6)) + ((setc_anx['setc_Happy_avg_arous_sev_anx'])*(unh_anx_tot3)*(7)) + ((setb_anx['setb_Happy_avg_arous_sev_anx'])*(unh_anx_tot2)*(6)) + ((seta_anx['seta_Happy_avg_arous_sev_anx'])*(unh_anx_tot1)*(6)))/((unh_anx_tot4*6)+(unh_anx_tot3*7)+(unh_anx_tot2*6)+(unh_anx_tot1*6)),2)])

myTable.add_row(["Sad", round((((setd_anx['setd_Sad_avg_arous_non_anx'])*(h_anx_tot4)*(6)) + ((setc_anx['setc_Sad_avg_arous_non_anx'])*(h_anx_tot3)*(6)) + ((setb_anx['setb_Sad_avg_arous_non_anx'])*(h_anx_tot2)*(7)) + ((seta_anx['seta_Sad_avg_arous_non_anx'])*(h_anx_tot1)*(6)))/(h_anx_tot4*(6)+h_anx_tot3*(6)+h_anx_tot2*(7)+h_anx_tot1*(6)),2),
                 round((((setd_anx['setd_Sad_avg_arous_sev_anx'])*(unh_anx_tot4)*(6)) + ((setc_anx['setc_Sad_avg_arous_sev_anx'])*(unh_anx_tot3)*(6)) + ((setb_anx['setb_Sad_avg_arous_sev_anx'])*(unh_anx_tot2)*(7)) + ((seta_anx['seta_Sad_avg_arous_sev_anx'])*(unh_anx_tot1)*(6)))/(unh_anx_tot4*(6)+unh_anx_tot3*(6)+unh_anx_tot2*(7)+unh_anx_tot1*(6)),2)])

myTable.add_row(["Angry", round((((setd_anx['setd_Angry_avg_arous_non_anx'])*(h_anx_tot4)*(7)) + ((setc_anx['setc_Angry_avg_arous_non_anx'])*(h_anx_tot3)*(6)) + ((setb_anx['setb_Angry_avg_arous_non_anx'])*(h_anx_tot2)*(6)) + ((seta_anx['seta_Angry_avg_arous_non_anx'])*(h_anx_tot1)*(6)))/(h_anx_tot4*(7)+h_anx_tot3*(6)+h_anx_tot2*(6)+h_anx_tot1*(6)),2),
                 round((((setd_anx['setd_Angry_avg_arous_sev_anx'])*(unh_anx_tot4)*(7)) + ((setc_anx['setc_Angry_avg_arous_sev_anx'])*(unh_anx_tot3)*(6)) + ((setb_anx['setb_Angry_avg_arous_sev_anx'])*(unh_anx_tot2)*(6)) + ((seta_anx['seta_Angry_avg_arous_sev_anx'])*(unh_anx_tot1)*(6)))/(unh_anx_tot4*(7)+unh_anx_tot3*(6)+unh_anx_tot2*(6)+unh_anx_tot1*(6)),2)])

myTable.add_row(["Neutral", round((((setd_anx['setd_Neutral_avg_arous_non_anx'])*(h_anx_tot4)*(6)) + ((setc_anx['setc_Neutral_avg_arous_non_anx'])*(h_anx_tot3)*(6)) + ((setb_anx['setb_Neutral_avg_arous_non_anx'])*(h_anx_tot2)*(6)) + ((seta_anx['seta_Neutral_avg_arous_non_anx'])*(h_anx_tot1)*(7)))/(h_anx_tot4*(6)+h_anx_tot3*(6)+h_anx_tot2*(6)+h_anx_tot1*(7)),2),
                 round((((setd_anx['setd_Neutral_avg_arous_sev_anx'])*(unh_anx_tot4)*(6)) + ((setc_anx['setc_Neutral_avg_arous_sev_anx'])*(unh_anx_tot3)*(6)) + ((setb_anx['setb_Neutral_avg_arous_sev_anx'])*(unh_anx_tot2)*(6)) + ((seta_anx['seta_Neutral_avg_arous_sev_anx'])*(unh_anx_tot1)*(7)))/(unh_anx_tot4*(6)+unh_anx_tot3*(6)+unh_anx_tot2*(6)+unh_anx_tot1*(7)),2)])
print('For Arousal ~ Mean ~ All Sets')
print(myTable)
# Out:
# For Arousal ~ Mean ~ All Sets
# +-----------------------------------------+
# |        Arousal ~ Mean ~ All Sets        |
# +---------+--------------+----------------+
# | Emotion | Healthy : 75 | Unhealthy : 22 |
# +---------+--------------+----------------+
# |  Happy  |     3.36     |      3.58      |
# |   Sad   |     2.23     |      2.11      |
# |  Angry  |     3.72     |      3.78      |
# | Neutral |     2.22     |      2.28      |
# +---------+--------------+----------------+

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_anx_tot1+h_anx_tot2+h_anx_tot3+h_anx_tot4), 'Unhealthy : %s' % str(unh_anx_tot1+unh_anx_tot2+unh_anx_tot3+unh_anx_tot4)])
myTable.title = 'Valence ~ Standard Deviation ~ All Sets [N = 97]'
# Add rows
# print(all_sets_std_anx.keys())
myTable.add_row(["Happy", round(all_sets_std_anx['all_sets_Happy_std_dev_val_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Happy_std_dev_val_sev_anx'],2)
                 ])
myTable.add_row(["Sad", round(all_sets_std_anx['all_sets_Sad_std_dev_val_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Sad_std_dev_val_sev_anx'],2)
                 ])
myTable.add_row(["Angry", round(all_sets_std_anx['all_sets_Angry_std_dev_val_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Angry_std_dev_val_sev_anx'],2)
                 ])
myTable.add_row(["Neutral", round(all_sets_std_anx['all_sets_Neutral_std_dev_val_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Neutral_std_dev_val_sev_anx'],2)
                 ])
print('Valence ~ Standard Deviation ~ All Sets [N=97]')
print(myTable)
# Out:
# Valence ~ Standard Deviation ~ All Sets [N=97]
# +--------------------------------------------------+
# | Valence ~ Standard Deviation ~ All Sets [N = 97] |
# +----------+-----------------+---------------------+
# | Emotion  |   Healthy : 75  |    Unhealthy : 22   |
# +----------+-----------------+---------------------+
# |  Happy   |       0.88      |         0.93        |
# |   Sad    |       1.01      |         0.93        |
# |  Angry   |       1.08      |         1.15        |
# | Neutral  |       0.92      |         0.94        |
# +----------+-----------------+---------------------+

# %%
myTable = PrettyTable(['Emotion', 'Healthy : %s' % str(h_anx_tot1+h_anx_tot2+h_anx_tot3+h_anx_tot4), 'Unhealthy : %s' % str(unh_anx_tot1+unh_anx_tot2+unh_anx_tot3+unh_anx_tot4)])
myTable.title = 'Arousal ~ Standard Deviation ~ All Sets [N = 97]'
# Add rows
# print(all_sets_std_anx.keys())
myTable.add_row(["Happy", round(all_sets_std_anx['all_sets_Happy_std_dev_arous_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Happy_std_dev_arous_sev_anx'],2)
                 ])
myTable.add_row(["Sad", round(all_sets_std_anx['all_sets_Sad_std_dev_arous_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Sad_std_dev_arous_sev_anx'],2)
                 ])
myTable.add_row(["Angry", round(all_sets_std_anx['all_sets_Angry_std_dev_arous_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Angry_std_dev_arous_sev_anx'],2)
                 ])
myTable.add_row(["Neutral", round(all_sets_std_anx['all_sets_Neutral_std_dev_arous_non_anx'],2),
                 round(all_sets_std_anx['all_sets_Neutral_std_dev_arous_sev_anx'],2)
                 ])
print('Arousal ~ Standard Deviation ~ All Sets [N=97]')
print(myTable)
# Out:
# Arousal ~ Standard Deviation ~ All Sets [N=97]
# +--------------------------------------------------+
# | Arousal ~ Standard Deviation ~ All Sets [N = 97] |
# +----------+-----------------+---------------------+
# | Emotion  |   Healthy : 75  |    Unhealthy : 22   |
# +----------+-----------------+---------------------+
# |  Happy   |       1.1       |         1.05        |
# |   Sad    |       1.04      |         0.99        |
# |  Angry   |       1.11      |         1.13        |
# | Neutral  |       0.98      |         0.96        |
# +----------+-----------------+---------------------+

# %% [markdown]
# # PANAS DATA & Violin Plot

# %%
PANAS_h_data = pd.DataFrame(columns =['PANAS_Category', 'PANAS_Values'])
PANAS_unh_data = pd.DataFrame(columns =['PANAS_Category', 'PANAS_Values'])

# %%
for i in range(1, 5):
    df = globals()[f"df_merged_{i}"]
    for index, row in df.iterrows():
      if (row["total_phq_score"] < 9):
          new_row_pos = {'PANAS_Category': 'PANAS_pos', 'PANAS_Values': row['total_panas_pos']}
          new_row_neg = {'PANAS_Category': 'PANAS_neg', 'PANAS_Values': row['total_panas_neg']}
          PANAS_h_data = PANAS_h_data.append(new_row_pos, ignore_index=True)
          PANAS_h_data = PANAS_h_data.append(new_row_neg, ignore_index=True)
      else:
          new_row_pos = {'PANAS_Category': 'PANAS_pos', 'PANAS_Values': row['total_panas_pos']}
          new_row_neg = {'PANAS_Category': 'PANAS_neg', 'PANAS_Values': row['total_panas_neg']}
          PANAS_unh_data = PANAS_unh_data.append(new_row_pos, ignore_index=True)
          PANAS_unh_data = PANAS_unh_data.append(new_row_neg, ignore_index=True)
# Out:
# <ipython-input-65-5efe806a8c15>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   PANAS_h_data = PANAS_h_data.append(new_row_pos, ignore_index=True)
# <ipython-input-65-5efe806a8c15>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   PANAS_h_data = PANAS_h_data.append(new_row_neg, ignore_index=True)
# <ipython-input-65-5efe806a8c15>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   PANAS_unh_data = PANAS_unh_data.append(new_row_pos, ignore_index=True)
# <ipython-input-65-5efe806a8c15>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   PANAS_unh_data = PANAS_unh_data.append(new_row_neg, ignore_index=True)
# ...

# %% [markdown]
# ## Violin PANAS Plot for Healthy

# %%
plt.figure(figsize=(5, 3))
plt.title('Healthy category')


# Plotting violin plots
sns.violinplot(x='PANAS_Category', y='PANAS_Values', data=PANAS_h_data, fill = False, palette='colorblind',linewidth=0.8, width = 0.3, inner = 'box')
plt.tight_layout()

plt.savefig('panas_healthy.pdf', bbox_inches='tight')
# Show the plot
plt.show()
# Out:
# <ipython-input-66-2f2b26ef3579>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='PANAS_Category', y='PANAS_Values', data=PANAS_h_data, fill = False, palette='colorblind',linewidth=0.8, width = 0.3, inner = 'box')

# %% [markdown]
# ## Violin PANAS plot for Unhealthy

# %%
plt.figure(figsize=(5, 3))
plt.title('Unhealthy category')


# Plotting violin plots
sns.violinplot(x='PANAS_Category', y='PANAS_Values', data=PANAS_unh_data, fill = False, palette='colorblind',linewidth=0.8, width = 0.3, inner = 'box')
plt.tight_layout()

plt.savefig('panas_unhealthy.pdf', bbox_inches='tight')
# Show the plot
plt.show()
# Out:
# <ipython-input-67-a832e7d31878>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='PANAS_Category', y='PANAS_Values', data=PANAS_unh_data, fill = False, palette='colorblind',linewidth=0.8, width = 0.3, inner = 'box')

# %% [markdown]
# # For Poster (R&D showcase 2024)

# %%
import matplotlib.pyplot as plt

# Sample data for demonstration
# Replace this with your actual data
phq_categories = ['Minimal ', 'Mild', 'Moderate', 'Severe']
gad_categories = ['Minimal', 'Mild', 'Moderate', 'Severe']
phq_counts = [27, 44, 13, 13]  # Replace with actual counts
gad_counts = [48, 29, 15, 5]   # Replace with actual counts

# Calculate total counts for normalization
total_phq = sum(phq_counts)
total_gad = sum(gad_counts)

# Calculate percentages
phq_percentages = [count / total_phq * 100 for count in phq_counts]
gad_percentages = [count / total_gad * 100 for count in gad_counts]

# Plotting
fig, ax = plt.subplots()

bar_width = 0.35
index = range(len(phq_categories))

phq_bar = ax.bar(index, phq_counts, bar_width, label='Self Reported Depressed', color = "#feb24c")
gad_bar = ax.bar([i + bar_width for i in index], gad_counts, bar_width, label='Self Reported Anxious', color = "#a1d99b")

# Add percentages inside the bars
for i, bar in enumerate(phq_bar):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() / 2,
            f'{phq_percentages[i]:.1f}%\n ({phq_counts[i]})', ha='center', va='center')

for i, bar in enumerate(gad_bar):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() / 2,
            f'{gad_percentages[i]:.1f}%\n ({gad_counts[i]})', ha='center', va='center')

ax.set_xlabel('Categories')
ax.set_ylabel('Number of Participants')
ax.set_title('Participants (N=97)')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(phq_categories)

ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for demonstration
# Replace this with your actual data
phq_categories = ['Minimal', 'Mild', 'Moderate', 'Severe']
gad_categories = ['Minimal', 'Mild', 'Moderate', 'Severe']
phq_counts = [27, 44, 13, 13]  # Replace with actual counts
gad_counts = [48, 29, 15, 5]   # Replace with actual counts

# Calculate total counts for normalization
total_phq = sum(phq_counts)
total_gad = sum(gad_counts)

# Calculate percentages
phq_percentages = np.array(phq_counts) / total_phq * 100
gad_percentages = np.array(gad_counts) / total_gad * 100

# Plotting PHQ data
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

colors = ['#1f78b4', '#33a02c', '#e31a1c', '#ff7f00']  # Colorblind-friendly palette
plt.pie(phq_counts, labels=phq_categories, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('PHQ Data')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Plotting GAD data
plt.subplot(1, 2, 2)

colors = ['#1f78b4', '#33a02c', '#e31a1c', '#ff7f00']  # Colorblind-friendly palette
plt.pie(gad_counts, labels=gad_categories, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('GAD Data')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for demonstration
# Replace this with your actual data
phq_categories = ['Minimal', 'Mild', 'Moderate', 'Severe']
gad_categories = ['Minimal', 'Mild', 'Moderate', 'Severe']
phq_counts = [27, 44, 13, 13]  # Replace with actual counts
gad_counts = [48, 29, 15, 5]   # Replace with actual counts

# Calculate total counts for normalization
total_phq = sum(phq_counts)
total_gad = sum(gad_counts)

# Calculate percentages
phq_percentages = np.array(phq_counts) / total_phq * 100
gad_percentages = np.array(gad_counts) / total_gad * 100

# Plotting PHQ data
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

colors = ['#33a02c', '#1f78b4', '#ff7f00', '#e31a1c']  # Colorblind-friendly palette
plt.pie(phq_counts, labels=phq_categories, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('PHQ Data')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Drawing a white circle to create the donut plot effect for PHQ data
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Plotting GAD data
plt.subplot(1, 2, 2)

colors = ['#1f78b4', '#33a02c', '#e31a1c', '#ff7f00']  # Colorblind-friendly palette
plt.pie(gad_counts, labels=gad_categories, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('GAD Data')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Drawing a white circle to create the donut plot effect for GAD data
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.tight_layout()
plt.savefig('phq_gad_donut.pdf', bbox_inches='tight')
plt.show()
